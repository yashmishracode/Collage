# %% [markdown]
# Revision of unit 1

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
a=5
b=11
print(b/a)
b//a
# Out:
# 2.2
# 2

# %%
l1=[int(x) for x in input("Enter no").split()]
print(l1)
# Out:
# Enter no 12 12 121 12 12
# [12, 12, 121, 12, 12]

# %%
t1=(10,)
type(t1)
t1
# Out:
# (10,)

# %%
s= input("Enter")
s1={eval(e) for e in s.split()}
s1
# Out:
# Enter 12 34 21 54 21
# {12, 21, 34, 54}

# %%
d1 = dict(a="apple")
d1
# Out:
# {'a': 'apple'}

# %%
d1['a']="man"
d1
# Out:
# {'a': 'man', 5: 'man'}

# %%
def avg(*t):
    A = sum(t)/len(t)
    return A
print("avg is",avg(10,12))
# Out:
# avg is 11.0

# %% [markdown]
# Recursion function

# %%
def f1(n):
    if n==1 :
        return 1
    s = n *  f1(n-1)
    return s

r= f1(6)
r
# Out:
# 720
